# %% [markdown]
# ##### Libraries:

# %%
import pandas as pd
import os
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta

# %% [markdown]
# ##### Load and concatenate data:

# %%
path = 'data/' # path of files
files = os.listdir(path) # list of files in the folder 
files_turbine = [file for file in files if str(file).startswith('Turbine')]

# %%
def data_selection(data, turbine, year):
    col_indices = data.columns[[0, 61, 63, 64, 65, 62, 1, 2, 3, 4, 82, 85, 84, 83, 90, 107, 106, 105, 91, 110, 109, 108,
                       92, 153, 152, 151, 93, 138, 137, 136, 94, 123, 116, 115, 95, 150, 149, 148, 96, 135, 134,
                       133, 97, 122, 120, 119, 98, 121, 118, 117, 99, 126, 125, 124, 100, 156, 155, 154, 101, 129,
                       127, 128, 102, 132, 131, 130, 103, 141, 140, 139, 104, 147, 146, 145, 111, 159, 158, 157,
                       112, 162, 161, 160, 113, 165, 164, 163, 114, 144, 143, 142, 210, 245, 251, 250, 249, 246,
                       254, 253, 252, 247, 257, 256, 255, 261, 262, 287, 288, 289]]
    df = data[col_indices].copy()
    col_names = ["Date.time", 
        "Power.me", "Power.sd", "Power.min", "Power.max", 
        "Pot.Power.me", 
        "Wind.speed.me", "Wind.speed.sd", "Wind.speed.min", "Wind.speed.max", 
        "Power.factor.cosphi.me", "Power.factor.cosphi.sd", "Power.factor.cosphi.min", "Power.factor.cosphi.max",
        "Front.bearing.temp.me", "Front.bearing.temp.sd", "Front.bearing.temp.min", "Front.bearing.temp.max",
        "Rear.bearing.temp.me", "Rear.bearing.temp.sd", "Rear.bearing.temp.min", "Rear.bearing.temp.max",
        "Stator1.temp.me", "Stator1.temp.sd", "Stator1.temp.min", "Stator1.temp.max",
        "Nacelle.ambient.temp.me", "Nacelle.ambient.temp.sd", "Nacelle.ambient.temp.min", "Nacelle.ambient.temp.max",
        "Nacelle.temp.me", "Nacelle.temp.sd", "Nacelle.temp.min", "Nacelle.temp.max",
        "Transformer.temp.me", "Transformer.temp.sd", "Transformer.temp.min", "Transformer.temp.max",
        "Gear.oil.inlet.temp.me", "Gear.oil.inlet.temp.sd", "Gear.oil.inlet.temp.min", "Gear.oil.inlet.temp.max",
        "Generator.bearing.rear.temp.me", "Generator.bearing.rear.temp.sd", "Generator.bearing.rear.temp.min", "Generator.bearing.rear.temp.max",
        "Generator.bearing.front.temp.me", "Generator.bearing.front.temp.sd", "Generator.bearing.front.temp.min", "Generator.bearing.front.temp.max",
        "Gear.oil.temp.me", "Gear.oil.temp.sd", "Gear.oil.temp.min", "Gear.oil.temp.max",
        "Top.box.temp.me", "Top.box.temp.sd", "Top.box.temp.min", "Top.box.temp.max",
        "Hub.temp.me", "Hub.temp.sd", "Hub.temp.min", "Hub.temp.max",
        "Conv.Amb.temp.me", "Conv.Amb.temp.sd", "Conv.Amb.temp.min", "Conv.Amb.temp.max",
        "Rotor.bearing.temp.me", "Rotor.bearing.temp.sd", "Rotor.bearing.temp.min", "Rotor.bearing.temp.max",
        "Transformer.cell.temp.me", "Transformer.cell.temp.sd", "Transformer.cell.temp.min", "Transformer.cell.temp.max",
        "Motor.axis1.temp.me", "Motor.axis1.temp.sd", "Motor.axis1.temp.min", "Motor.axis1.temp.max",
        "Motor.axis2.temp.me", "Motor.axis2.temp.sd", "Motor.axis2.temp.min", "Motor.axis2.temp.max", 
        "Motor.axis3.temp.me", "Motor.axis3.temp.sd", "Motor.axis3.temp.min", "Motor.axis3.temp.max",
        "CPU.temp.me", "CPU.temp.sd", "CPU.temp.min", "CPU.temp.max", 
        "Rotor.speed.me", 
        "Blade.ang.pitch.pos.A.me", "Blade.ang.pitch.pos.A.sd", "Blade.ang.pitch.pos.A.min", "Blade.ang.pitch.pos.A.max", 
        "Blade.ang.pitch.pos.B.me", "Blade.ang.pitch.pos.B.sd", "Blade.ang.pitch.pos.B.min", "Blade.ang.pitch.pos.B.max", 
        "Blade.ang.pitch.pos.C.me", "Blade.ang.pitch.pos.C.sd", "Blade.ang.pitch.pos.C.min", "Blade.ang.pitch.pos.C.max", 
        "Gear.oil.inlet.press.me", "Gear.oil.pump.press.me", "Drive.train.acceleration.me", 
        "Tower.Acceleration.x", "Tower.Acceleration.y"]
    df.columns = col_names
    df["turbine"] = turbine
    df["year"] = year
    return df

# %%
def concatenate_files(files):
    dfs = []
    for file in files_turbine:
        turbine = int(str(file).split('_')[3])
        year = int(str(file).split('_')[4][:4])
        df_old = pd.read_csv(path + file, skiprows=range(0, 9))
        df = data_selection(df_old, turbine, year)
        dfs.append(df)
    df_concatenated = pd.concat(dfs, ignore_index=True) 
    return df_concatenated

# %%
DATETIME_COL = 'Date.time'
df = concatenate_files(files_turbine)
df.head()
# Out:
#              Date.time  Power.me  Power.sd  Power.min  Power.max  \
# 0  2016-01-03 00:00:00       NaN       NaN        NaN        NaN
# 1  2016-01-03 00:10:00       NaN       NaN        NaN        NaN
# 2  2016-01-03 00:20:00       NaN       NaN        NaN        NaN
# 3  2016-01-03 00:30:00       NaN       NaN        NaN        NaN
# 4  2016-01-03 00:40:00       NaN       NaN        NaN        NaN
#
#    Pot.Power.me  Wind.speed.me  Wind.speed.sd  Wind.speed.min  Wind.speed.max  \
# 0           NaN            NaN            NaN             NaN             NaN
# 1           NaN            NaN            NaN             NaN             NaN
# 2           NaN            NaN            NaN             NaN             NaN
# 3           NaN            NaN            NaN             NaN             NaN
# 4           NaN            NaN            NaN             NaN             NaN
#
#    ...  Blade.ang.pitch.pos.C.sd  Blade.ang.pitch.pos.C.min  \
# 0  ...                       NaN                        NaN
# 1  ...                       NaN                        NaN
# 2  ...                       NaN                        NaN
# 3  ...                       NaN                        NaN
# 4  ...                       NaN                        NaN
#
#    Blade.ang.pitch.pos.C.max  Gear.oil.inlet.press.me  Gear.oil.pump.press.me  \
# 0                        NaN                      NaN                     NaN
# 1                        NaN                      NaN                     NaN
# 2                        NaN                      NaN                     NaN
# 3                        NaN                      NaN                     NaN
# 4                        NaN                      NaN                     NaN
#
#    Drive.train.acceleration.me  Tower.Acceleration.x  Tower.Acceleration.y  \
# 0                          NaN                   NaN                   NaN
# 1                          NaN                   NaN                   NaN
# 2                          NaN                   NaN                   NaN
# 3                          NaN                   NaN                   NaN
# 4                          NaN                   NaN                   NaN
#
#    turbine  year
# 0        1  2016
# 1        1  2016
# 2        1  2016
# 3        1  2016
# 4        1  2016
#
# [5 rows x 110 columns]

# %%
print("Print total number of datapoints before filtering: ", len(df))
# Out:
# Print total number of datapoints before filtering:  1733184

# %% [markdown]
# ##### Pre-process data:

# %% [markdown]
# Standard deviations and minimal and maximal values provide useful quantification of variability within the 10-minute intervals, for this reason, only data entries from the 25th of September 2017 were considered (i.e., when the SCADA monitoring system started recording standard deviations).
#
# - One observation is that we have more NaN values in wind speed std than in power std.
# - I select to keep the dataframe that has fully completed the wind speed std and power std column.

# %%
df_final = df[~df['Wind.speed.sd'].isnull()] # select rows with entries for wind speed std
df_final.head()
# Out:
#                  Date.time    Power.me   Power.sd   Power.min   Power.max  \
# 90864  2017-09-25 00:00:00  200.121521  23.819124  157.306244  240.665955
# 90865  2017-09-25 00:10:00  196.931503  11.779391  174.080612  224.724045
# 90866  2017-09-25 00:20:00  197.651825  11.052958  174.656937  214.682724
# 90867  2017-09-25 00:30:00  182.931046   9.611711  167.144882  198.324615
# 90868  2017-09-25 00:40:00  202.370926   7.406655  183.193558  211.172287
#
#        Pot.Power.me  Wind.speed.me  Wind.speed.sd  Wind.speed.min  \
# 90864    236.830036       5.171129       0.390980        4.240140
# 90865    221.866237       5.090679       0.436131        4.303428
# 90866    240.928125       5.193162       0.305424        4.739578
# 90867    204.527186       4.995740       0.258361        4.488607
# 90868    225.665257       5.111104       0.296016        4.674517
#
#        Wind.speed.max  ...  Blade.ang.pitch.pos.C.sd  \
# 90864        5.912565  ...                       NaN
# 90865        5.930200  ...                       NaN
# 90866        5.894996  ...                       NaN
# 90867        5.601314  ...                       NaN
# 90868        5.677069  ...                       NaN
#
#        Blade.ang.pitch.pos.C.min  Blade.ang.pitch.pos.C.max  \
# 90864                        NaN                        NaN
# 90865                        NaN                        NaN
# 90866                        NaN                        NaN
# 90867                        NaN                        NaN
# 90868                        NaN                        NaN
#
#        Gear.oil.inlet.press.me  Gear.oil.pump.press.me  \
# 90864                80.076599              355.346771
# 90865                79.719238              353.837952
# 90866                79.778137              353.752502
# 90867                78.186005              348.852203
# 90868                79.173264              351.041290
#
#        Drive.train.acceleration.me  Tower.Acceleration.x  \
# 90864                    44.632309             22.022369
# 90865                    43.258904             20.714163
# 90866                    41.394890             23.446747
# 90867                    43.366161             18.103645
# 90868                    41.450455             19.340059
#
#        Tower.Acceleration.y  turbine  year
# 90864             14.627177        1  2017
# 90865             10.469490        1  2017
# 90866             11.127916        1  2017
# 90867             11.582632        1  2017
# 90868             12.164517        1  2017
#
# [5 rows x 110 columns]

# %%
print('Deleted because of NaNs in wind speed std and power std columns: ', 
      round((df.shape[0] - df_final.shape[0]) / df.shape[0] * 100, 1) ,'% of the total data.')
# Out:
# Deleted because of NaNs in wind speed std and power std columns:  32.5 % of the total data.

# %% [markdown]
# ##### Load Status file:

# %%
status_df = pd.read_excel(DATA_PATH + 'status_file/status.xlsx', sheet_name = 'Status file')
status_df.head()
# Out:
#    Wind Turbine     Timestamp start        Timestamp end             Duration  \
# 0             1 2016-01-14 19:28:03  2016-01-23 14:36:32  1900-01-08 19:08:29
# 1             1 2016-01-14 19:28:03  2016-01-14 19:38:03             00:10:00
# 2             1 2016-01-14 19:28:05  2016-01-23 11:27:46  1900-01-08 15:59:41
# 3             1 2016-01-14 19:28:05  2016-01-23 11:27:46  1900-01-08 15:59:41
# 4             1 2016-01-14 19:28:05  2016-01-23 14:09:18  1900-01-08 18:41:13
#
#           Status  Code                              Message  Comment  \
# 0           Stop   111               Emergency stop nacelle      NaN
# 1        Warning  5720             Brake accumulator defect      NaN
# 2  Informational  3835             Cable panel breaker open      NaN
# 3  Informational  3830       Supply circuit breaker earthed      NaN
# 4        Warning  3870  Overload transformer fan outlet air      NaN
#
#               Service contract category      IEC category
# 0  Emergency stop switch (Nacelle) (11)     Forced outage
# 1                         Warnings (27)               NaN
# 2                         Warnings (27)               NaN
# 3                         Warnings (27)  Full Performance
# 4                         Warnings (27)  Full Performance

# %% [markdown]
# #### Data Cleaning  - Faults
# - Removing time intervals that are included in the status faults file:

# %%
df_final.reset_index(inplace=True) # reset index

# %%
ids = np.unique(status_df['Wind Turbine'])

index_fault = list()

df_final[DATETIME_COL] = df_final.loc[:, DATETIME_COL].astype('datetime64[ns]') # convert date and time in the same format in SCADA and status file

for id in ids:
    print('Preprocess of wind turbine:', id)
    
    start, end = list(), list()

    status = status_df[status_df['Wind Turbine'] == id]

    for tstamp_start in status['Timestamp start']:
        start.append(tstamp_start)

    for tstamp_end in status['Timestamp end']:
        end.append(tstamp_end)

    for x, y in zip(start, end):
        if not (isinstance(x, str) or isinstance(y, str)):
            exclude = np.where((df_final[DATETIME_COL] >= (x - timedelta(minutes=10))) & (df_final[DATETIME_COL] <= (y +  timedelta(minutes=10))) & (df_final.turbine == id))
            index_fault.append(exclude)

out = np.concatenate(index_fault, axis = 1).ravel().tolist()
out = pd.DataFrame(out)
# Out:
# <ipython-input-65-1b138c33384e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final[DATETIME_COL] = df_final[DATETIME_COL].astype('datetime64[ns]') # convert date and time in the same format in SCADA and status file
# Preprocess of wind turbine: 1
# Preprocess of wind turbine: 2
# Preprocess of wind turbine: 3
# Preprocess of wind turbine: 4
# Preprocess of wind turbine: 5
# Preprocess of wind turbine: 6

# %%
out = list(out[0])

# %%
# Data points removed

grid = sns.FacetGrid(df_final.loc[out], col ='turbine', col_wrap= 3)
grid.map(sns.scatterplot, 'Wind.speed.me', 'Power.me', alpha = .7, color="0.3", linewidth = 0, s = 2)
grid.add_legend()
grid.set_axis_labels("Wind Speed (m/s)", "Active Power (kW)")
plt.show()

# %%
df_cleaned = df_final.drop(out, axis=0)

# %%
# Data set after cleaning 

grid = sns.FacetGrid(df_cleaned, col ='turbine', col_wrap= 3)
grid.map(sns.scatterplot, 'Wind.speed.me', 'Power.me', alpha = .7, color="0.3", linewidth = 0, s = 2)
grid.add_legend()
grid.set_axis_labels("Wind Speed (m/s)", "Active Power (kW)")
plt.show()

# %%
n = df_cleaned.shape[0]
max_len = max(len(col) for col in df_cleaned.columns) + len("Column: ")
for col in df_cleaned.columns:
    nan_percentage = round((df_cleaned[col].isna().sum()/n)*100, 2)
    print(f"Column: {col.ljust(max_len)} has {nan_percentage}% of NaNs out of total")
# Out:
# Column: index                                    has 0.0% of NaNs out of total
# Column: Date.time                                has 0.0% of NaNs out of total
# Column: Power.me                                 has 0.0% of NaNs out of total
# Column: Power.sd                                 has 0.0% of NaNs out of total
# Column: Power.min                                has 0.0% of NaNs out of total
# Column: Power.max                                has 0.0% of NaNs out of total
# Column: Pot.Power.me                             has 0.0% of NaNs out of total
# Column: Wind.speed.me                            has 0.0% of NaNs out of total
# Column: Wind.speed.sd                            has 0.0% of NaNs out of total
# Column: Wind.speed.min                           has 0.0% of NaNs out of total
# Column: Wind.speed.max                           has 0.0% of NaNs out of total
# Column: Power.factor.cosphi.me                   has 0.0% of NaNs out of total
# Column: Power.factor.cosphi.sd                   has 0.0% of NaNs out of total
# Column: Power.factor.cosphi.min                  has 0.0% of NaNs out of total
# Column: Power.factor.cosphi.max                  has 0.0% of NaNs out of total
# Column: Front.bearing.temp.me                    has 0.0% of NaNs out of total
# Column: Front.bearing.temp.sd                    has 0.0% of NaNs out of total
# Column: Front.bearing.temp.min                   has 0.0% of NaNs out of total
# Column: Front.bearing.temp.max                   has 0.0% of NaNs out of total
# Column: Rear.bearing.temp.me                     has 0.0% of NaNs out of total
# Column: Rear.bearing.temp.sd                     has 0.0% of NaNs out of total
# Column: Rear.bearing.temp.min                    has 0.0% of NaNs out of total
# Column: Rear.bearing.temp.max                    has 0.0% of NaNs out of total
# Column: Stator1.temp.me                          has 0.0% of NaNs out of total
# Column: Stator1.temp.sd                          has 66.02% of NaNs out of total
# Column: Stator1.temp.min                         has 66.02% of NaNs out of total
# Column: Stator1.temp.max                         has 66.02% of NaNs out of total
# Column: Nacelle.ambient.temp.me                  has 0.0% of NaNs out of total
# Column: Nacelle.ambient.temp.sd                  has 66.02% of NaNs out of total
# Column: Nacelle.ambient.temp.min                 has 66.02% of NaNs out of total
# Column: Nacelle.ambient.temp.max                 has 66.02% of NaNs out of total
# Column: Nacelle.temp.me                          has 0.0% of NaNs out of total
# Column: Nacelle.temp.sd                          has 47.96% of NaNs out of total
# Column: Nacelle.temp.min                         has 13.3% of NaNs out of total
# Column: Nacelle.temp.max                         has 13.3% of NaNs out of total
# Column: Transformer.temp.me                      has 0.0% of NaNs out of total
# Column: Transformer.temp.sd                      has 66.02% of NaNs out of total
# Column: Transformer.temp.min                     has 66.02% of NaNs out of total
# Column: Transformer.temp.max                     has 66.02% of NaNs out of total
# Column: Gear.oil.inlet.temp.me                   has 0.0% of NaNs out of total
# Column: Gear.oil.inlet.temp.sd                   has 66.02% of NaNs out of total
# Column: Gear.oil.inlet.temp.min                  has 66.02% of NaNs out of total
# Column: Gear.oil.inlet.temp.max                  has 66.02% of NaNs out of total
# Column: Generator.bearing.rear.temp.me           has 0.0% of NaNs out of total
# Column: Generator.bearing.rear.temp.sd           has 40.39% of NaNs out of total
# Column: Generator.bearing.rear.temp.min          has 13.3% of NaNs out of total
# Column: Generator.bearing.rear.temp.max          has 13.3% of NaNs out of total
# Column: Generator.bearing.front.temp.me          has 0.0% of NaNs out of total
# Column: Generator.bearing.front.temp.sd          has 40.39% of NaNs out of total
# Column: Generator.bearing.front.temp.min         has 13.3% of NaNs out of total
# Column: Generator.bearing.front.temp.max         has 13.3% of NaNs out of total
# Column: Gear.oil.temp.me                         has 0.0% of NaNs out of total
# Column: Gear.oil.temp.sd                         has 48.39% of NaNs out of total
# Column: Gear.oil.temp.min                        has 48.39% of NaNs out of total
# Column: Gear.oil.temp.max                        has 48.39% of NaNs out of total
# Column: Top.box.temp.me                          has 0.0% of NaNs out of total
# Column: Top.box.temp.sd                          has 66.02% of NaNs out of total
# Column: Top.box.temp.min                         has 66.02% of NaNs out of total
# Column: Top.box.temp.max                         has 66.02% of NaNs out of total
# Column: Hub.temp.me                              has 0.0% of NaNs out of total
# Column: Hub.temp.sd                              has 48.55% of NaNs out of total
# Column: Hub.temp.min                             has 48.55% of NaNs out of total
# Column: Hub.temp.max                             has 48.55% of NaNs out of total
# Column: Conv.Amb.temp.me                         has 0.0% of NaNs out of total
# Column: Conv.Amb.temp.sd                         has 66.02% of NaNs out of total
# Column: Conv.Amb.temp.min                        has 66.02% of NaNs out of total
# Column: Conv.Amb.temp.max                        has 66.02% of NaNs out of total
# Column: Rotor.bearing.temp.me                    has 0.0% of NaNs out of total
# Column: Rotor.bearing.temp.sd                    has 66.02% of NaNs out of total
# Column: Rotor.bearing.temp.min                   has 66.02% of NaNs out of total
# Column: Rotor.bearing.temp.max                   has 66.02% of NaNs out of total
# Column: Transformer.cell.temp.me                 has 0.0% of NaNs out of total
# Column: Transformer.cell.temp.sd                 has 66.02% of NaNs out of total
# Column: Transformer.cell.temp.min                has 66.02% of NaNs out of total
# Column: Transformer.cell.temp.max                has 66.02% of NaNs out of total
# Column: Motor.axis1.temp.me                      has 0.0% of NaNs out of total
# Column: Motor.axis1.temp.sd                      has 66.02% of NaNs out of total
# Column: Motor.axis1.temp.min                     has 66.02% of NaNs out of total
# Column: Motor.axis1.temp.max                     has 66.02% of NaNs out of total
# Column: Motor.axis2.temp.me                      has 0.0% of NaNs out of total
# Column: Motor.axis2.temp.sd                      has 66.02% of NaNs out of total
# Column: Motor.axis2.temp.min                     has 66.02% of NaNs out of total
# Column: Motor.axis2.temp.max                     has 66.02% of NaNs out of total
# Column: Motor.axis3.temp.me                      has 13.23% of NaNs out of total
# Column: Motor.axis3.temp.sd                      has 66.02% of NaNs out of total
# Column: Motor.axis3.temp.min                     has 66.02% of NaNs out of total
# Column: Motor.axis3.temp.max                     has 66.02% of NaNs out of total
# Column: CPU.temp.me                              has 0.0% of NaNs out of total
# Column: CPU.temp.sd                              has 66.02% of NaNs out of total
# Column: CPU.temp.min                             has 66.02% of NaNs out of total
# Column: CPU.temp.max                             has 66.02% of NaNs out of total
# Column: Rotor.speed.me                           has 0.0% of NaNs out of total
# Column: Blade.ang.pitch.pos.A.me                 has 0.0% of NaNs out of total
# Column: Blade.ang.pitch.pos.A.sd                 has 40.24% of NaNs out of total
# Column: Blade.ang.pitch.pos.A.min                has 40.24% of NaNs out of total
# Column: Blade.ang.pitch.pos.A.max                has 40.24% of NaNs out of total
# Column: Blade.ang.pitch.pos.B.me                 has 0.0% of NaNs out of total
# Column: Blade.ang.pitch.pos.B.sd                 has 40.24% of NaNs out of total
# Column: Blade.ang.pitch.pos.B.min                has 40.24% of NaNs out of total
# Column: Blade.ang.pitch.pos.B.max                has 40.24% of NaNs out of total
# Column: Blade.ang.pitch.pos.C.me                 has 0.0% of NaNs out of total
# Column: Blade.ang.pitch.pos.C.sd                 has 40.24% of NaNs out of total
# Column: Blade.ang.pitch.pos.C.min                has 40.24% of NaNs out of total
# Column: Blade.ang.pitch.pos.C.max                has 40.24% of NaNs out of total
# Column: Gear.oil.inlet.press.me                  has 0.0% of NaNs out of total
# Column: Gear.oil.pump.press.me                   has 0.0% of NaNs out of total
# Column: Drive.train.acceleration.me              has 0.01% of NaNs out of total
# Column: Tower.Acceleration.x                     has 0.0% of NaNs out of total
# Column: Tower.Acceleration.y                     has 0.0% of NaNs out of total
# Column: turbine                                  has 0.0% of NaNs out of total
# Column: year                                     has 0.0% of NaNs out of total

# %%
nans = df_cleaned[~df_cleaned.isnull().any(axis=1)].shape[0]
print("Percentage of rows with at least one NaN value: ", round(nans/n*100, 2))
# Out:
# Percentage of rows with at least one NaN value:  33.97

# %%
df_cleaned.head()
# Out:
#    index           Date.time    Power.me   Power.sd   Power.min   Power.max  \
# 0  90864 2017-09-25 00:00:00  200.121521  23.819124  157.306244  240.665955
# 1  90865 2017-09-25 00:10:00  196.931503  11.779391  174.080612  224.724045
# 2  90866 2017-09-25 00:20:00  197.651825  11.052958  174.656937  214.682724
# 3  90867 2017-09-25 00:30:00  182.931046   9.611711  167.144882  198.324615
# 4  90868 2017-09-25 00:40:00  202.370926   7.406655  183.193558  211.172287
#
#    Pot.Power.me  Wind.speed.me  Wind.speed.sd  Wind.speed.min  ...  \
# 0    236.830036       5.171129       0.390980        4.240140  ...
# 1    221.866237       5.090679       0.436131        4.303428  ...
# 2    240.928125       5.193162       0.305424        4.739578  ...
# 3    204.527186       4.995740       0.258361        4.488607  ...
# 4    225.665257       5.111104       0.296016        4.674517  ...
#
#    Blade.ang.pitch.pos.C.sd  Blade.ang.pitch.pos.C.min  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#    Blade.ang.pitch.pos.C.max  Gear.oil.inlet.press.me  Gear.oil.pump.press.me  \
# 0                        NaN                80.076599              355.346771
# 1                        NaN                79.719238              353.837952
# 2                        NaN                79.778137              353.752502
# 3                        NaN                78.186005              348.852203
# 4                        NaN                79.173264              351.041290
#
#    Drive.train.acceleration.me  Tower.Acceleration.x  Tower.Acceleration.y  \
# 0                    44.632309             22.022369             14.627177
# 1                    43.258904             20.714163             10.469490
# 2                    41.394890             23.446747             11.127916
# 3                    43.366161             18.103645             11.582632
# 4                    41.450455             19.340059             12.164517
#
#    turbine  year
# 0        1  2017
# 1        1  2017
# 2        1  2017
# 3        1  2017
# 4        1  2017
#
# [5 rows x 111 columns]

# %%
df_cleaned.drop(columns=['index']).to_pickle('Cleaned_data.pkl')
